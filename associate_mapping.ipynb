# %% [markdown]
# <a href="https://colab.research.google.com/github/sundarpa/connect_pairs/blob/main/associate_mapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from io import StringIO

# Input vectors CSV content
input_vectors_csv = """col1_col2_col3_col4_col5_col6_col7
word1_word2_INI_corei1_coreia1_word6_word7
word1_word2_INI_corei2_coreia2_word6_word7
word1_word2_INI_corei3_coreia3_word6_word7
word1_word2_INI_corei4_coreia4_word6_word7
word1_word2_INI_corei5_coreia5_word6_word7
word1_word2_body_coreb1_coreba1_word6_word7
word1_word2_body_corebw1_corebaq1_word6_word7
word1_word2_body_corebr1_corebat1_word6_word7
word1_word2_body_corebx2_corebay2_word6_word7
word1_word2_body_coreb3_coreba3_word6_word7
word1_word2_body_coreb4_coreba4_word6_word7
word1_word2_body_coreb5_coreba5_word6_word7
word1_word2_body_coreby_corebay_word6_word7
word1_word2_body1_coreb1_coreba1_word6_word7
word1_word2_body1_corebw1_corebaq1_word6_word7
word1_word2_body1_corebr1_corebat1_word6_word7
word1_word2_body1_corebx2_corebay2_word6_word7
word1_word2_body1_coreb3_coreba3_word6_word7
word1_word2_body1_coreb4_coreba4_word6_word7
word1_word2_body1_coreb5_coreba5_word6_word7
word1_word2_body1_coreby_corebay_word6_word7
word1_word2_body2_coreb1_coreba1_word6_word7
word1_word2_body2_corebw1_corebaq1_word6_word7
word1_word2_body2_corebr1_corebat1_word6_word7
word1_word2_body2_corebx2_corebay2_word6_word7
word1_word2_body2_coreb3_coreba3_word6_word7
word1_word2_body2_coreb4_coreba4_word6_word7
word1_word2_body2_coreb5_coreba5_word6_word7
word1_word2_body2_coreby_corebay_word6_word7
word1_word2_body3_coreb1_coreba1_word6_word7
word1_word2_body3_corebw1_corebaq1_word6_word7
word1_word2_body3_corebr1_corebat1_word6_word7
word1_word2_body3_corebx2_corebay2_word6_word7
word1_word2_body3_coreb3_coreba3_word6_word7
word1_word2_body3_coreb4_coreba4_word6_word7
word1_word2_body3_coreb5_coreba5_word6_word7
word1_word2_body3_coreby_corebay_word6_word7
"""

# Mapping table CSV content
mapping_csv = """ini_core1,ini_core2,body_core1,body_core2
corei1,coreia1,coreb1,coreba1
corei1,coreia1,corebw1,corebaq1
corei1,coreia1,corebr1,corebat1
corei2,coreia2,corebx2,corebay2
corei3,coreia3,coreb3,coreba3
corei4,coreia4,coreb4,coreba4
corei5,coreia5,coreb5,coreba5
corei5,coreia5,coreby,corebay
"""

# Use StringIO to create file-like objects for pandas to read from
input_data = StringIO(input_vectors_csv)
mapping_data = StringIO(mapping_csv)

# Read input vectors and mapping data into DataFrames
input_df = pd.read_csv(input_data, sep='_')
mapping_df = pd.read_csv(mapping_data)

# Filter rows in input_df containing 'INI' in col3
init_df = input_df[input_df['col3'] == 'INI']

# Filter rows in input_df containing 'body' in col3
body_df = input_df[input_df['col3'] != 'INI']

# Join init_df with mapping_df on specified conditions
init_mapped_df = pd.merge(init_df, mapping_df, left_on=['col4', 'col5'], right_on=['ini_core1', 'ini_core2'])

# Join body_df with mapping_df on specified conditions
body_mapped_df = pd.merge(body_df, mapping_df, left_on=['col4', 'col5'], right_on=['body_core1', 'body_core2'])

# Print the resulting DataFrames
print("init_mapped_df:")
print(init_mapped_df)

print("\nbody_mapped_df:")
print(body_mapped_df)


# Combine init_mapped_df and body_mapped_df column-wise into a single DataFrame named "init_body"
init_body = pd.concat([init_mapped_df, body_mapped_df], axis=1)

# Print the resulting init_body DataFrame
print("init_body:")
print(init_body)
# Out:
# init_mapped_df:
#     col1   col2 col3    col4     col5   col6   col7 ini_core1 ini_core2  \
# 0  word1  word2  INI  corei1  coreia1  word6  word7    corei1   coreia1
# 1  word1  word2  INI  corei1  coreia1  word6  word7    corei1   coreia1
# 2  word1  word2  INI  corei1  coreia1  word6  word7    corei1   coreia1
# 3  word1  word2  INI  corei2  coreia2  word6  word7    corei2   coreia2
# 4  word1  word2  INI  corei3  coreia3  word6  word7    corei3   coreia3
# 5  word1  word2  INI  corei4  coreia4  word6  word7    corei4   coreia4
# 6  word1  word2  INI  corei5  coreia5  word6  word7    corei5   coreia5
# 7  word1  word2  INI  corei5  coreia5  word6  word7    corei5   coreia5
#
#   body_core1 body_core2
# 0     coreb1    coreba1
# 1    corebw1   corebaq1
# 2    corebr1   corebat1
# 3    corebx2   corebay2
# 4     coreb3    coreba3
# 5     coreb4    coreba4
# 6     coreb5    coreba5
# 7     coreby    corebay
#
# body_mapped_df:
#      col1   col2   col3     col4      col5   col6   col7 ini_core1 ini_core2  \
# 0   word1  word2   body   coreb1   coreba1  word6  word7    corei1   coreia1
# 1   word1  word2  body1   coreb1   coreba1  word6  word7    corei1   coreia1
# 2   word1  word2  body2   coreb1   coreba1  word6  word7    corei1   coreia1
# 3   word1  word2  body3   coreb1   coreba1  word6  word7    corei1   coreia1
# 4   word1  word2   body  corebw1  corebaq1  word6  word7    corei1   coreia1
# 5   word1  word2  body1  corebw1  corebaq1  word6  word7    corei1   coreia1
# 6   word1  word2  body2  corebw1  corebaq1  word6  word7    corei1   coreia1
# 7   word1  word2  body3  corebw1  corebaq1  word6  word7    corei1   coreia1
# 8   word1  word2   body  corebr1  corebat1  word6  word7    corei1   coreia1
# 9   word1  word2  body1  corebr1  corebat1  word6  word7    corei1   coreia1
# 10  word1  word2  body2  corebr1  corebat1  word6  word7    corei1   coreia1
# 11  word1  word2  body3  corebr1  corebat1  word6  word7    corei1   coreia1
# 12  word1  word2   body  corebx2  corebay2  word6  word7    corei2   coreia2
# 13  word1  word2  body1  corebx2  corebay2  word6  word7    corei2   coreia2
# 14  word1  word2  body2  corebx2  corebay2  word6  word7    corei2   coreia2
# 15  word1  word2  body3  corebx2  corebay2  word6  word7    corei2   coreia2
# 16  word1  word2   body   coreb3   coreba3  word6  word7    corei3   coreia3
# 17  word1  word2  body1   coreb3   coreba3  word6  word7    corei3   coreia3
# 18  word1  word2  body2   coreb3   coreba3  word6  word7    corei3   coreia3
# 19  word1  word2  body3   coreb3   coreba3  word6  word7    corei3   coreia3
# 20  word1  word2   body   coreb4   coreba4  word6  word7    corei4   coreia4
# 21  word1  word2  body1   coreb4   coreba4  word6  word7    corei4   coreia4
# 22  word1  word2  body2   coreb4   coreba4  word6  word7    corei4   coreia4
# 23  word1  word2  body3   coreb4   coreba4  word6  word7    corei4   coreia4
# 24  word1  word2   body   coreb5   coreba5  word6  word7    corei5   coreia5
# 25  word1  word2  body1   coreb5   coreba5  word6  word7    corei5   coreia5
# 26  word1  word2  body2   coreb5   coreba5  word6  word7    corei5   coreia5
# 27  word1  word2  body3   coreb5   coreba5  word6  word7    corei5   coreia5
# 28  word1  word2   body   coreby   corebay  word6  word7    corei5   coreia5
# 29  word1  word2  body1   coreby   corebay  word6  word7    corei5   coreia5
# 30  word1  word2  body2   coreby   corebay  word6  word7    corei5   coreia5
# 31  word1  word2  body3   coreby   corebay  word6  word7    corei5   coreia5
#
#    body_core1 body_core2
# 0      coreb1    coreba1
# 1      coreb1    coreba1
# 2      coreb1    coreba1
# 3      coreb1    coreba1
# 4     corebw1   corebaq1
# 5     corebw1   corebaq1
# 6     corebw1   corebaq1
# 7     corebw1   corebaq1
# 8     corebr1   corebat1
# 9     corebr1   corebat1
# 10    corebr1   corebat1
# 11    corebr1   corebat1
# 12    corebx2   corebay2
# 13    corebx2   corebay2
# 14    corebx2   corebay2
# 15    corebx2   corebay2
# 16     coreb3    coreba3
# 17     coreb3    coreba3
# 18     coreb3    coreba3
# 19     coreb3    coreba3
# 20     coreb4    coreba4
# 21     coreb4    coreba4
# 22     coreb4    coreba4
# 23     coreb4    coreba4
# 24     coreb5    coreba5
# 25     coreb5    coreba5
# 26     coreb5    coreba5
# 27     coreb5    coreba5
# 28     coreby    corebay
# 29     coreby    corebay
# 30     coreby    corebay
# 31     coreby    corebay
# init_body:
#      col1   col2 col3    col4     col5   col6   col7 ini_core1 ini_core2  \
# 0   word1  word2  INI  corei1  coreia1  word6  word7    corei1   coreia1
# 1   word1  word2  INI  corei1  coreia1  word6  word7    corei1   coreia1
# 2   word1  word2  INI  corei1  coreia1  word6  word7    corei1   coreia1
# 3   word1  word2  INI  corei2  coreia2  word6  word7    corei2   coreia2
# 4   word1  word2  INI  corei3  coreia3  word6  word7    corei3   coreia3
# 5   word1  word2  INI  corei4  coreia4  word6  word7    corei4   coreia4
# 6   word1  word2  INI  corei5  coreia5  word6  word7    corei5   coreia5
# 7   word1  word2  INI  corei5  coreia5  word6  word7    corei5   coreia5
# 8     NaN    NaN  NaN     NaN      NaN    NaN    NaN       NaN       NaN
# 9     NaN    NaN  NaN     NaN      NaN    NaN    NaN       NaN       NaN
# 10    NaN    NaN  NaN     NaN      NaN    NaN    NaN       NaN       NaN
# 11    NaN    NaN  NaN     NaN      NaN    NaN    NaN       NaN       NaN
# 12    NaN    NaN  NaN     NaN      NaN    NaN    NaN       NaN       NaN
# 13    NaN    NaN  NaN     NaN      NaN    NaN    NaN       NaN       NaN
# 14    NaN    NaN  NaN     NaN      NaN    NaN    NaN       NaN       NaN
# 15    NaN    NaN  NaN     NaN      NaN    NaN    NaN       NaN       NaN
# 16    NaN    NaN  NaN     NaN      NaN    NaN    NaN       NaN       NaN
# 17    NaN    NaN  NaN     NaN      NaN    NaN    NaN       NaN       NaN
# 18    NaN    NaN  NaN     NaN      NaN    NaN    NaN       NaN       NaN
# 19    NaN    NaN  NaN     NaN      NaN    NaN    NaN       NaN       NaN
# 20    NaN    NaN  NaN     NaN      NaN    NaN    NaN       NaN       NaN
# 21    NaN    NaN  NaN     NaN      NaN    NaN    NaN       NaN       NaN
# 22    NaN    NaN  NaN     NaN      NaN    NaN    NaN       NaN       NaN
# 23    NaN    NaN  NaN     NaN      NaN    NaN    NaN       NaN       NaN
# 24    NaN    NaN  NaN     NaN      NaN    NaN    NaN       NaN       NaN
# 25    NaN    NaN  NaN     NaN      NaN    NaN    NaN       NaN       NaN
# 26    NaN    NaN  NaN     NaN      NaN    NaN    NaN       NaN       NaN
# 27    NaN    NaN  NaN     NaN      NaN    NaN    NaN       NaN       NaN
# 28    NaN    NaN  NaN     NaN      NaN    NaN    NaN       NaN       NaN
# 29    NaN    NaN  NaN     NaN      NaN    NaN    NaN       NaN       NaN
# 30    NaN    NaN  NaN     NaN      NaN    NaN    NaN       NaN       NaN
# 31    NaN    NaN  NaN     NaN      NaN    NaN    NaN       NaN       NaN
#
#    body_core1  ...   col2   col3     col4      col5   col6   col7 ini_core1  \
# 0      coreb1  ...  word2   body   coreb1   coreba1  word6  word7    corei1
# 1     corebw1  ...  word2  body1   coreb1   coreba1  word6  word7    corei1
# 2     corebr1  ...  word2  body2   coreb1   coreba1  word6  word7    corei1
# 3     corebx2  ...  word2  body3   coreb1   coreba1  word6  word7    corei1
# 4      coreb3  ...  word2   body  corebw1  corebaq1  word6  word7    corei1
# 5      coreb4  ...  word2  body1  corebw1  corebaq1  word6  word7    corei1
# 6      coreb5  ...  word2  body2  corebw1  corebaq1  word6  word7    corei1
# 7      coreby  ...  word2  body3  corebw1  corebaq1  word6  word7    corei1
# 8         NaN  ...  word2   body  corebr1  corebat1  word6  word7    corei1
# 9         NaN  ...  word2  body1  corebr1  corebat1  word6  word7    corei1
# 10        NaN  ...  word2  body2  corebr1  corebat1  word6  word7    corei1
# 11        NaN  ...  word2  body3  corebr1  corebat1  word6  word7    corei1
# 12        NaN  ...  word2   body  corebx2  corebay2  word6  word7    corei2
# 13        NaN  ...  word2  body1  corebx2  corebay2  word6  word7    corei2
# 14        NaN  ...  word2  body2  corebx2  corebay2  word6  word7    corei2
# 15        NaN  ...  word2  body3  corebx2  corebay2  word6  word7    corei2
# 16        NaN  ...  word2   body   coreb3   coreba3  word6  word7    corei3
# 17        NaN  ...  word2  body1   coreb3   coreba3  word6  word7    corei3
# 18        NaN  ...  word2  body2   coreb3   coreba3  word6  word7    corei3
# 19        NaN  ...  word2  body3   coreb3   coreba3  word6  word7    corei3
# 20        NaN  ...  word2   body   coreb4   coreba4  word6  word7    corei4
# 21        NaN  ...  word2  body1   coreb4   coreba4  word6  word7    corei4
# 22        NaN  ...  word2  body2   coreb4   coreba4  word6  word7    corei4
# 23        NaN  ...  word2  body3   coreb4   coreba4  word6  word7    corei4
# 24        NaN  ...  word2   body   coreb5   coreba5  word6  word7    corei5
# 25        NaN  ...  word2  body1   coreb5   coreba5  word6  word7    corei5
# 26        NaN  ...  word2  body2   coreb5   coreba5  word6  word7    corei5
# 27        NaN  ...  word2  body3   coreb5   coreba5  word6  word7    corei5
# 28        NaN  ...  word2   body   coreby   corebay  word6  word7    corei5
# 29        NaN  ...  word2  body1   coreby   corebay  word6  word7    corei5
# 30        NaN  ...  word2  body2   coreby   corebay  word6  word7    corei5
# 31        NaN  ...  word2  body3   coreby   corebay  word6  word7    corei5
#
#    ini_core2 body_core1 body_core2
# 0    coreia1     coreb1    coreba1
# 1    coreia1     coreb1    coreba1
# 2    coreia1     coreb1    coreba1
# 3    coreia1     coreb1    coreba1
# 4    coreia1    corebw1   corebaq1
# 5    coreia1    corebw1   corebaq1
# 6    coreia1    corebw1   corebaq1
# 7    coreia1    corebw1   corebaq1
# 8    coreia1    corebr1   corebat1
# 9    coreia1    corebr1   corebat1
# 10   coreia1    corebr1   corebat1
# 11   coreia1    corebr1   corebat1
# 12   coreia2    corebx2   corebay2
# 13   coreia2    corebx2   corebay2
# 14   coreia2    corebx2   corebay2
# 15   coreia2    corebx2   corebay2
# 16   coreia3     coreb3    coreba3
# 17   coreia3     coreb3    coreba3
# 18   coreia3     coreb3    coreba3
# 19   coreia3     coreb3    coreba3
# 20   coreia4     coreb4    coreba4
# 21   coreia4     coreb4    coreba4
# 22   coreia4     coreb4    coreba4
# 23   coreia4     coreb4    coreba4
# 24   coreia5     coreb5    coreba5
# 25   coreia5     coreb5    coreba5
# 26   coreia5     coreb5    coreba5
# 27   coreia5     coreb5    coreba5
# 28   coreia5     coreby    corebay
# 29   coreia5     coreby    corebay
# 30   coreia5     coreby    corebay
# 31   coreia5     coreby    corebay
#
# [32 rows x 22 columns]
